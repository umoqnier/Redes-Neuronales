# %% [markdown]
# # Laboratorio de Redes Neuronales 🥼

# %% [markdown]
# ## Orden del día

# %% [markdown]
# * ¿Qué vamos a trabajar?
# * Objetivos
# * ¿Cómo vamos a trabajar?
#   *  Metodología de entrega de prácticas
# * Sobre mi y contacto

# %% [markdown]
# ## Temario

# %% [markdown]
# ### 1. Aprendizaje estadístico

# %% [markdown]
# - Tipos de aprendizaje
# - Entrenamiento y evaluación
# - Representación de datos
# - Regresión lineal y logística

# %% [markdown]
# <center><img src="https://www.themachinelearners.com/wp-content/uploads/2020/06/1280px-Linear_regression.svg_.png" width=400></center>

# %% [markdown]
# ### 2. El perceptrón

# %% [markdown]
# - Aprendizaje en el perceptrón
# - Separabilidad líneal
# - Modelo de una neurona

# %% [markdown]
# <center><img src="https://www.researchgate.net/publication/364436953/figure/fig1/AS:11431281091020013@1666284306285/Example-of-Perceptron-network-Input-features-X-1-X-2-X-n-are-multiplied-with.png" width=500></center>

# %% [markdown]
# ### 3. Redes *feedforward*

# %% [markdown]
# - Capas ocultas
#     - Funciones de activación
# - Redes neuronales profundas

# %% [markdown]
# <center><img src="https://dataaspirant.com/wp-content/uploads/2020/09/7-feed-forward.png" width=500></center>

# %% [markdown]
# ### 4. Aprendizaje en redes multicapa

# %% [markdown]
# - Decenso por gradiente
#     - Lotes
#     - Mini lotes
# - Optimizadores
#     - Retropropagación
# - Métodos de regularización

# %% [markdown]
# <center><img src="https://vitalflux.com/wp-content/uploads/2020/10/feed_forward_neural_network-1.gif"></center>

# %% [markdown]
# ### 5. Temas avanzados

# %% [markdown]
# - Redes recurrentes
# - Redes convolucionales
# - Redes atencionales

# %% [markdown]
# <center><img src="https://mchromiak.github.io/articles/2017/Sep/12/Transformer-Attention-is-all-you-need/img/MultiHead.png" width=500></center>

# %% [markdown]
# ## Objetivo del laboratorio

# %% [markdown]
# - Practicar lo que vean en clase :)
#     - Profundizar en uso de herramientas para desarrollo de soluciones utilizando redes neuronales
# - Programar elementos fundamentales de las redes neuronales como los que se listan:
#     - Neuronas artificiales
#     - Redes profundas
#     - Estrategias de optimización
#         - Basadas en gradiente por descenso
#         - Basadas en retro-propagación
# - Aplicar los conocimientos vistos para solucionar un problema complejo con base en datos no estructurados

# %% [markdown]
# <center><img src="http://i0.kym-cdn.com/entries/icons/facebook/000/008/342/ihave.jpg"></center>

# %% [markdown]
# ## ¿Qué vamos a trabajar?

# %% [markdown]
# - Este laboratorio que cubre los aspectos prácticos de la clase teórica
#     - Programación en `python` con un enfoque `OOP`
#     - Herramientas a utilizar: `pytorch`, `numpy`, `sklearn`, `jupyter` y las que se me olvidó poner
# - Deberán desarrollar y entregar `~3` prácticas no guiadas
#     - Varias prácticas guiadas acumulativas
#     - La práctica final será de tema libre
# - Se publicarán los requisitos de las prácticas a entregar en *classroom*

# %% [markdown]
# ## Metodología de entregas

# %% [markdown]
# Entregables serán a través de *classroom*. Las entregas **deberán** ser notebooks de Google colab

# %% [markdown]
# 1. Crear sus notebooks desde https://colab.research.google.com/
#
# <center><img src="img/new_notebook.png" width=400></center>

# %% [markdown]
# 2. Si trabajan con notebooks locales sube tu práctica `.ipynb` a tu unidad de Drive desde https://colab.research.google.com/
#
# <center><img src="img/upload.png" width=400></center>

# %% [markdown]
# 3. Seleccionar Drive
#
# <center><img src="img/drive.png" width=200></center>

# %% [markdown]
# 4. En la entrega seleccionar el notebook de colab (**No el notebook `.ipynb`**)
#
# <center><img src="img/colab_notebook.png" width=300></center>

# %% [markdown]
# ### Notas 📝
#
# - Es muy recomendable entregar las prácticas ya que representa un porcentaje importante de su calificación 🤓
# - Se dará una pequeña toleracia para entregar prácticas (`~5 minutos`) ⌛
#     - En caso de **entregas tardías** abrá una penalización `-1 punto` por cada día
# - Si utilizas LLMs, o herramientas generativas **reportalas en tus prácticas** 🧙🏼‍♀️
#   - Les recomendamos ampliamente que lo intenten por su cuenta
#   - Es una oportunidad de enfrentarse a cosas nuevas y de pensar en soluciones :)

# %% [markdown]
# ## Sobre mi y contacto

# %% [markdown]
# - Me llamo Diego Barriga (asies, como el Señor Barriga)
# - Recien ingresado a la Maestría en Ciencias de la Computación 🐣
# - Ex-Meli como MLOps engineer
# - Hice [mi tesis](https://github.com/umoqnier/otomi-morph-segmenter) sobre NLP y lenguas originarias mexicanas
#     - [Etiquetador automático de la morfología del otomí usando predicción estructurada](http://www.ptolomeo.unam.mx:8080/xmlui/bitstream/handle/RepoFi/18221/Tesis.pdf?sequence=11)
# - Desarrollo y promuevo el software libre en [Comunidad Elotl](https://github.com/ElotlMX/) y [LIDSoL](https://github.com/LIDSOL/)
# - Me late la cultura libre, andar en bici (sin frenos) y uso arch BTW
#
# <div style="display: flex; justify-content: space-between;">
#     <a href="https://elotl.mx/" target="_blank"><img src="img/elotl.png" style="width: 30%;"></a>
#     <a href="https://lidsol.org/" target="_blank"><img src="https://www.lidsol.org/img/logo.png" style="width: 80%;"></a>
# </div>

# %% [markdown]
# ## `https://github.com/umoqnier/Redes-Neuronales/`

# %% [markdown]
# <center><img src="img/qr.png"></center>

# %% [markdown]
# ### Contacto
#
# - dbarriga@ciencias.unam.mx
# - En la clase Lunes de 16:00 a 18:00, Lab. Sistemas Operativos :p
# - Probablemente en este [lidsol](https://lidsol.unam.mx/#contact) o en el [IIMAS](https://turing.iimas.unam.mx/contacto/)
